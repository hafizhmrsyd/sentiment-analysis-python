# %%
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen, Request
import pandas as pd

# %%
def sanber():
    alamat = "https://blog.sanbercode.com/"
    
    user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.182 Safari/537.36'
    headers = {'User-Agent' : user_agent, 'Accept' : 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9'}
    
    req = Request(alamat, headers=headers)
    html = urlopen(req)
    data = bs(html, 'html.parser')
    
    items = data.findAll("a", {"class":"text-dark"})
    
    for item in items:
        print(item.get_text().strip())

# %%
# def wiki()
alamat = 'https://en.wikipedia.org/wiki/List_of_brightest_stars'

user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.182 Safari/537.36'
headers = {'User-Agent' : user_agent, 'Accept' : 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9'}

req = Request(alamat, headers=headers)
html = urlopen(req)
data = bs(html, 'html.parser')

table = data.find('table', {'class':'wikitable'})
rows = table.findAll('tr')

hasil = []
for row in rows:
    sel = row.findAll(['td','th'])

    items = []
    for item in sel:
        items.append(item.get_text().strip())

    hasil.append(items)

df = pd.DataFrame(hasil)

# %%
df
# Out:
#          0                      1               2                  3  \
# 0     Rank  Visual magnitude (mV)  Proper name[1]  Bayer designation
# 1   part 1                 part 2            None               None
# 2        1            0.000−26.74             Sun
# 3        2             0.001−1.46          Sirius                  α
# 4        3             0.003−0.74         Canopus                  α
# ..     ...                    ...             ...                ...
# 90      89                   2.46          Markeb                  κ
# 91      90      2.47 (1.6–3.0var)         Navi[a]                  γ
# 92      91                   2.48          Markab                  α
# 93      92                   2.48         Aljanah                  ε
# 94      93                   2.50           Acrab                  β
#
#                 4               5                        6
# 0   Distance (ly)  Spectral class                     None
# 1            None            None                     None
# 2     0.000015813            G2 V                     None
# 3             CMa          0008.6            A0mA1 Va, DA2
# 4             Car            0310                    A9 II
# ..            ...             ...                      ...
# 90            Vel            0540                    B2 IV
# 91            Cas            0610                 B0.5 IVe
# 92            Peg            0140                    A0 IV
# 93            Cyg            0072                K0 III-IV
# 94            Sco            0404  B0.5 IV-V, B1.5 V, B2 V
#
# [95 rows x 7 columns]

# %%
df.columns = ["Rank", "Visual magnitude (mV)", "Proper name", "Bayer Designation Part 1", "Bayer Designation Part 2", "Distance (ly)", "Spectral Class"]

# %%
df
# Out:
#       Rank  Visual magnitude (mV)     Proper name Bayer Designation Part 1  \
# 0     Rank  Visual magnitude (mV)  Proper name[1]        Bayer designation
# 1   part 1                 part 2            None                     None
# 2        1            0.000−26.74             Sun
# 3        2             0.001−1.46          Sirius                        α
# 4        3             0.003−0.74         Canopus                        α
# ..     ...                    ...             ...                      ...
# 90      89                   2.46          Markeb                        κ
# 91      90      2.47 (1.6–3.0var)         Navi[a]                        γ
# 92      91                   2.48          Markab                        α
# 93      92                   2.48         Aljanah                        ε
# 94      93                   2.50           Acrab                        β
#
#    Bayer Designation Part 2   Distance (ly)           Spectral Class
# 0             Distance (ly)  Spectral class                     None
# 1                      None            None                     None
# 2               0.000015813            G2 V                     None
# 3                       CMa          0008.6            A0mA1 Va, DA2
# 4                       Car            0310                    A9 II
# ..                      ...             ...                      ...
# 90                      Vel            0540                    B2 IV
# 91                      Cas            0610                 B0.5 IVe
# 92                      Peg            0140                    A0 IV
# 93                      Cyg            0072                K0 III-IV
# 94                      Sco            0404  B0.5 IV-V, B1.5 V, B2 V
#
# [95 rows x 7 columns]

# %%
df = df.drop(df.index[[0,1,2]])

# %%
df = df.reset_index(drop=True)

# %%
df.dtypes
# Out:
# Rank                        object
# Visual magnitude (mV)       object
# Proper name                 object
# Bayer Designation Part 1    object
# Bayer Designation Part 2    object
# Distance (ly)               object
# Spectral Class              object
# dtype: object

# %%
df
# Out:
#    Rank     Visual magnitude (mV)                Proper name  \
# 0     2                0.001−1.46                     Sirius
# 1     3                0.003−0.74                    Canopus
# 2     4  0.004−0.27 (0.01 + 1.33)  Rigil Kentaurus & Toliman
# 3     5                0.005−0.05                   Arcturus
# 4     6      0.03 (−0.02–0.07var)                       Vega
# ..  ...                       ...                        ...
# 87   89                      2.46                     Markeb
# 88   90         2.47 (1.6–3.0var)                    Navi[a]
# 89   91                      2.48                     Markab
# 90   92                      2.48                    Aljanah
# 91   93                      2.50                      Acrab
#
#    Bayer Designation Part 1 Bayer Designation Part 2 Distance (ly)  \
# 0                         α                      CMa        0008.6
# 1                         α                      Car          0310
# 2                         α                      Cen        0004.4
# 3                         α                      Boo          0037
# 4                         α                      Lyr          0025
# ..                      ...                      ...           ...
# 87                        κ                      Vel          0540
# 88                        γ                      Cas          0610
# 89                        α                      Peg          0140
# 90                        ε                      Cyg          0072
# 91                        β                      Sco          0404
#
#              Spectral Class
# 0             A0mA1 Va, DA2
# 1                     A9 II
# 2                G2 V, K1 V
# 3                    K0 III
# 4                     A0 Va
# ..                      ...
# 87                    B2 IV
# 88                 B0.5 IVe
# 89                    A0 IV
# 90                K0 III-IV
# 91  B0.5 IV-V, B1.5 V, B2 V
#
# [92 rows x 7 columns]
